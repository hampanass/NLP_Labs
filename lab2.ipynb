# %% [markdown]
# <a href="https://colab.research.google.com/github/hampanass/NLP_Labs/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import re
import nltk
import spacy

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 86.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
text="Thiss PHONE is Amazng!!! I buyed it last wek, and the battry life is sooo goood but the camra quality isnt that greaat."

# %% [markdown]
# ##Text Normalisation

# %%
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Thiss', 'PHONE', 'is', 'Amazng', '!', '!', '!', 'I', 'buyed', 'it', 'last', 'wek', ',', 'and', 'the', 'battry', 'life', 'is', 'sooo', 'goood', 'but', 'the', 'camra', 'quality', 'isnt', 'that', 'greaat', '.']

# %%
text= re.sub(r"[^\w\s]", "", text)
print(text)
# Out:
# Thiss PHONE is Amazng I buyed it last wek and the battry life is sooo goood but the camra quality isnt that greaat

# %%
lower_tokens = [word.lower() for word in tokens]
print(lower_tokens)
# Out:
# ['thiss', 'phone', 'is', 'amazng', '!', '!', '!', 'i', 'buyed', 'it', 'last', 'wek', ',', 'and', 'the', 'battry', 'life', 'is', 'sooo', 'goood', 'but', 'the', 'camra', 'quality', 'isnt', 'that', 'greaat', '.']

# %% [markdown]
# #Tokenization

# %%
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Thiss', 'PHONE', 'is', 'Amazng', 'I', 'buyed', 'it', 'last', 'wek', 'and', 'the', 'battry', 'life', 'is', 'sooo', 'goood', 'but', 'the', 'camra', 'quality', 'isnt', 'that', 'greaat']

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)
for token in doc:
    print(token.text)
# Out:
# This
# s
# PHONE
# is
# Amazng
# I
# buyed
# it
# last
# wek
# and
# the
# battry
# life
# is
# sooo
# goood
# but
# the
# camra
# quality
# is
# nt
# that
# greaat

# %% [markdown]
# #Removing Stop words

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in lower_tokens if word.isalpha() and word not in stop_words]
print(filtered_tokens)
# Out:
# ['thiss', 'phone', 'amazng', 'buyed', 'last', 'wek', 'battry', 'life', 'sooo', 'goood', 'camra', 'quality', 'isnt', 'greaat']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)
for token in doc:
    print(token.text, '→',token.is_stop)
# Out:
# This → True
# s → False
# PHONE → False
# is → True
# Amazng → False
# I → True
# buyed → False
# it → True
# last → True
# wek → False
# and → True
# the → True
# battry → False
# life → False
# is → True
# sooo → False
# goood → False
# but → True
# the → True
# camra → False
# quality → False
# is → True
# nt → False
# that → True
# greaat → False

# %% [markdown]
# #Stemming using NLTK Porter Stemmer

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()
stemmed_words = [ps.stem(word) for word in filtered_tokens]
print(stemmed_words)
# Out:
# ['thiss', 'phone', 'amazng', 'buy', 'last', 'wek', 'battri', 'life', 'sooo', 'goood', 'camra', 'qualiti', 'isnt', 'greaat']

# %% [markdown]
# #Lemmatization using NLTK WordNet Lemmatizer and spaCy lemmatizer

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print(lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ['thiss', 'phone', 'amazng', 'buyed', 'last', 'wek', 'battry', 'life', 'sooo', 'goood', 'camra', 'quality', 'isnt', 'greaat']

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)
for token in doc:
    print(token.text, '→', token.lemma_)
# Out:
# This → this
# s → s
# PHONE → phone
# is → be
# Amazng → Amazng
# I → I
# buyed → buy
# it → it
# last → last
# wek → wek
# and → and
# the → the
# battry → battry
# life → life
# is → be
# sooo → sooo
# goood → goood
# but → but
# the → the
# camra → camra
# quality → quality
# is → be
# nt → not
# that → that
# greaat → greaat

# %% [markdown]
# ####Compute edit distance using NLTK with substitution cost = 1 and = 2

# %%
s1 = "buyed"
s2 = "buy"
dist_nltk = nltk.edit_distance(s1, s2)
print(f"--- Standard NLTK (Sub=1) ---")
print(f"Distance ('{s1}' -> '{s2}'): {dist_nltk}")
# Out:
# --- Standard NLTK (Sub=1) ---
# Distance ('buyed' -> 'buy'): 2

# %%
dist = nltk.edit_distance("buyed", "buy", substitution_cost=2)
print(f"Edit Distance: {dist}")
# Out:
# Edit Distance: 2
